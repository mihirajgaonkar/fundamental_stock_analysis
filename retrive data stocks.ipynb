# %%
import yfinance as yf
import json
import numpy as np
import os
import pandas as pd
from stock_file_creation import SYMBOLS

# %%
# Dictionary to collect data to create a DF later
data = {
    'Symbol': [],
    'Name': [],
    'Industry': [],
    'EPS (fwd)': [],
    'P/E (fwd)': [],
    'PEG': [],
    'FCFY' : [],
    'PB': [],
    'ROE' : [],
    'P/S (trail)': [],
    'DPR' : [],
    'DY' : [],
    'CR' : [],
    'Beta': [],
    'Price': [],
    '52w Low': [],
    '52w High': []
    }

#function to append data to dictionary
def load_data(json_data):
    data['Symbol'].append(json_data.get('symbol'))
    data['Name'].append(json_data.get('longName'))
    data['Industry'].append(json_data.get('industry'))
    data['Price'].append(json_data.get('currentPrice'))

    # Could be that some indicators are not available; use NaN if this is the case
    
    if 'forwardEps' in json_data:
        data['EPS (fwd)'].append(json_data.get('forwardEps'))
    else:
        data['EPS (fwd)'].append(np.nan)
        
    if 'forwardPE' in json_data:
        data['P/E (fwd)'].append(json_data.get('forwardPE'))
    else:
        data['P/E (fwd)'].append(np.nan)
        
    if 'pegRatio' in json_data:
        data['PEG'].append(json_data.get('pegRatio'))
    else:
        data['PEG'].append(np.nan)

    if ('freeCashflow' in json_data and json_data.get('freeCashflow') is not None) and ('marketCap' in json_data and json_data.get('marketCap') is not None):
        fcfy = (json_data.get('freeCashflow') / json_data.get('marketCap')) * 100
        data['FCFY'].append(round(fcfy, 2))
    else:
        data['FCFY'].append(np.nan)


    if 'priceToBook' in json_data:
        data['PB'].append(json_data.get('priceToBook'))
    else:
        data['PB'].append(np.nan)

    if 'returnOnEquity' in json_data:
        data['ROE'].append(json_data.get('returnOnEquity'))
    else:
        data['ROE'].append(np.nan)
        
    if 'priceToSalesTrailing12Months' in json_data:
        data['P/S (trail)'].append(json_data.get('priceToSalesTrailing12Months'))
    else:
        data['P/S (trail)'].append(np.nan)

    if json_data.get('payoutRatio') is not None:
        data['DPR'].append(json_data.get('payoutRatio') * 100)
    else:
        data['DPR'].append(np.nan)

    if 'dividendYield' in json_data:
        data['DY'].append(json_data.get('dividendYield'))
    else:
        data['DY'].append(0.0)

    if 'beta' in json_data:
        data['Beta'].append(json_data.get('beta'))
    else:
        data['Beta'].append(np.nan)

    if 'currentRatio' in json_data:
        data['CR'].append(json_data.get('currentRatio'))
    else:
        data['CR'].append(np.nan)

    if 'fiftyTwoWeekLow' in json_data:
        data['52w Low'].append(json_data.get('fiftyTwoWeekLow'))
    else:
        data['52w Low'].append(np.nan)
        
    if 'fiftyTwoWeekHigh' in json_data:    
        data['52w High'].append(json_data.get('fiftyTwoWeekHigh'))
    else:
        data['52w High'].append(np.nan)

for symbol in SYMBOLS:
    # Specify the full path to load JSON data
    file_name = f'C:/D/Other/Data Engineering/yfinance/stockout/{symbol}.json'    
    
    try:
        # Open the file in read mode
        with open(file_name, 'r') as file:
            # Use json.load() to parse the JSON data from the file
            load_data(json.load(file))
    except FileNotFoundError:
        print(f"File '{file_name}' not found.")
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON data: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
df = pd.DataFrame(data)

# Save any stocks with NaN values
df_exceptions = df[df.isna().any(axis=1)]

# Remove any stocks with NaN values
df=df.dropna()

# Reset index after dropping rows with NaN values
df.reset_index(drop=True, inplace=True)

# Add 52 week price range
df['52w Range'] = ((df['Price'] - df['52w Low'])/(df['52w High'] - df['52w Low']))*100

df_exceptions
# Out:
#    Symbol                  Name                   Industry  EPS (fwd)  \
# 0    APPL                  None                       None        NaN
# 10    JPM  JPMorgan Chase & Co.        Banks - Diversified      15.75
# 20   ADBE            Adobe Inc.  Software - Infrastructure      20.36
# 22    CRM      Salesforce, Inc.     Software - Application       9.56
#
#     P/E (fwd)   PEG  FCFY         PB      ROE  P/S (trail)        DPR      DY  \
# 0         NaN   NaN   NaN        NaN      NaN          NaN        NaN  0.0000
# 10  10.937778  3.45   NaN   1.717547  0.16932     3.496671  24.159999  0.0244
# 20  27.730843  2.20   NaN  15.552432  0.35513    13.244494        NaN  0.0000
# 22  26.267780  1.15  4.74   4.188963  0.04414     7.159220        NaN  0.0000
#
#        CR   Beta   Price  52w Low  52w High
# 0     NaN    NaN     NaN      NaN       NaN
# 10    NaN  1.111  172.27   123.11    173.38
# 20  1.343  1.330  564.60   318.60    633.89
# 22  1.042  1.281  251.12   142.59    268.36

# %%
df
# Out:
#    Symbol                             Name                        Industry  \
# 0    MSFT            Microsoft Corporation       Software - Infrastructure
# 1    AMZN                 Amazon.com, Inc.                 Internet Retail
# 2    NVDA               NVIDIA Corporation                  Semiconductors
# 3   GOOGL                    Alphabet Inc.  Internet Content & Information
# 4    TSLA                      Tesla, Inc.              Auto Manufacturers
# 5    META             Meta Platforms, Inc.  Internet Content & Information
# 6     UNH  UnitedHealth Group Incorporated                Healthcare Plans
# 7     XOM          Exxon Mobil Corporation            Oil & Gas Integrated
# 8    AVGO                    Broadcom Inc.                  Semiconductors
# 9     LLY            Eli Lilly and Company    Drug Manufacturers - General
# 10      V                        Visa Inc.                 Credit Services
# 11    JNJ                Johnson & Johnson    Drug Manufacturers - General
# 12     HD             The Home Depot, Inc.         Home Improvement Retail
# 13     MA          Mastercard Incorporated                 Credit Services
# 14     PG     The Procter & Gamble Company   Household & Personal Products
# 15   COST     Costco Wholesale Corporation                 Discount Stores
# 16   ABBV                      AbbVie Inc.    Drug Manufacturers - General
# 17    MRK                Merck & Co., Inc.    Drug Manufacturers - General
# 18    CVX              Chevron Corporation            Oil & Gas Integrated
#
#     EPS (fwd)  P/E (fwd)    PEG  FCFY          PB       ROE  P/S (trail)  \
# 0       12.96  28.375770   2.12  1.87   12.381321   0.39107    12.519875
# 1        3.61  40.232690   0.62  2.42    8.199628   0.12531     2.709087
# 2       20.44  24.020058   0.39  1.16   36.397804   0.69173    27.026876
# 3        6.69  20.288490   1.21  4.14    6.230434   0.25334     5.749289
# 4        3.78  62.828045  94.24  0.21   14.121180   0.22460     7.870415
# 5       17.54  20.065563   0.76  3.25    6.333340   0.22275     7.124218
# 6       27.89  19.267840   1.69  4.32    5.882971   0.25299     1.380725
# 7        9.17  11.191930  -1.04  5.04    2.036592   0.21168     1.170659
# 8       55.42  18.933239   1.63  2.74   17.718039   0.60312    13.713699
# 9       12.38  49.963650   3.24  0.66   49.575220   0.46461    18.308329
# 10      11.17  23.248880   1.89  3.13   14.184509   0.46487    16.344969
# 11      10.69  15.072967   3.13  5.46    5.445421   0.19190     3.931693
# 12      15.62  21.955187  12.64  4.31  238.816160  11.51320     2.220456
# 13      14.24  29.453653   1.65  2.57   62.404404   1.70446    16.141586
# 14       6.92  21.303467   2.95  3.79    7.411392   0.33203     4.172854
# 15      17.09  38.385605   4.76  2.39   11.134289   0.27369     1.184969
# 16      11.17  14.515667  -3.52  8.41   23.670073   0.46321     5.191785
# 17       8.50  13.790588   7.94  1.91    7.205114   0.10769     5.007803
# 18      14.08  10.681818  -1.78  6.42    1.717954   0.15678     1.400665
#
#            DPR      DY     CR   Beta    Price  52w Low  52w High  52w Range
# 0    26.360000  0.0082  1.663  0.876   367.75   226.41    384.30  89.518019
# 1     0.000000  0.0000  0.985  1.163   145.24    87.08    155.63  84.843180
# 2     2.110000  0.0003  3.588  1.642   490.97   151.41    505.48  95.901940
# 3     0.000000  0.0000  2.043  1.054   135.73    85.83    142.68  87.774846
# 4     0.000000  0.0000  1.690  2.316   237.49   114.92    299.29  66.480447
# 5     0.000000  0.0000  2.567  1.221   351.95   127.15    361.90  95.761448
# 6    30.640000  0.0140  0.773  0.564   537.38   445.68    554.70  84.113007
# 7    36.150002  0.0370  1.421  0.960   102.63    97.48    120.70  22.179156
# 8    55.790000  0.0200  2.815  1.241  1049.28   549.99   1151.82  82.961966
# 9    79.170000  0.0084  1.046  0.307   618.55   309.20    636.41  94.541732
# 10   21.740000  0.0080  1.452  0.951   259.69   208.76    263.25  93.466691
# 11   87.050000  0.0295  1.210  0.531   161.13   144.95    179.76  46.480896
# 12   52.370000  0.0244  1.302  0.977   342.94   274.26    354.92  85.147533
# 13   19.180000  0.0063  1.170  1.093   419.42   340.21    428.36  89.858196
# 14   60.190000  0.0255  0.671  0.438   147.42   135.83    158.38  51.396896
# 15   26.990000  0.0062  1.090  0.751   656.01   465.33    681.91  88.041370
# 16  160.270000  0.0382  0.955  0.470   162.14   130.96    166.28  88.278596
# 17  162.220000  0.0263  1.384  0.359   117.22    99.14    119.65  88.152121
# 18   44.169998  0.0402  1.255  1.113   150.40   140.72    187.81  20.556381

# %%
def make_pretty(styler):
    # Column formatting
    styler.format({'EPS (fwd)': '${:.2f}', 'P/E (fwd)': '{:.2f}', 'PEG': '{:.2f}',
                   'FCFY': '{:.2f}%', 'PB' : '{:.2f}', 'ROE' : '{:.2f}', 'P/S (trail)': '{:.2f}',
                   'DPR': '{:.2f}%', 'DY': '{:.2f}%', 'CR' : '{:.2f}', 'Beta': '{:.2f}', '52w Low': '${:.2f}',
                   'Price': '${:.2f}', '52w High': '${:.2f}', '52w Range': '{:.2f}%'
                  })
    # Set the bar visualization
    styler.bar(subset = ['52w Range'], align = "mid", color = ["salmon", "cornflowerblue"])

    # Grid
    styler.set_properties(**{'border': '0.1px solid black'})

    # Set background gradients
    styler.background_gradient(subset=['EPS (fwd)'], cmap='Greens')
    styler.background_gradient(subset=['P/E (fwd)'], cmap='Greens')
    styler.background_gradient(subset=['PEG'], cmap='Greens')
    styler.background_gradient(subset=['FCFY'], cmap='Greens')
    styler.background_gradient(subset=['PB'], cmap='Greens')
    styler.background_gradient(subset=['ROE'], cmap='Greens')
    styler.background_gradient(subset=['P/S (trail)'], cmap='Greens')
    styler.background_gradient(subset=['DPR'], cmap='Greens')
    styler.background_gradient(subset=['DY'], cmap='Greens')
    styler.background_gradient(subset=['CR'], cmap='Greens')

    # No index
    styler.hide(axis='index')

    # Tooltips
    styler.set_tooltips(
        ttips, css_class='tt-add',
        props=[
            ('visibility', 'hidden'),
            ('position', 'absolute'),
            ('background-color', 'salmon'),
            ('color', 'black'),
            ('z-index', 1),
            ('padding', '3px 3px'),
            ('margin', '2px')
        ]
    )
    # Left text alignment for some columns
    styler.set_properties(subset=['Symbol', 'Name', 'Industry'], **{'text-align': 'left'})
    return styler

# %%
def populate_tt(df, tt_data, col_name):
    stats = df[col_name].describe()
    
    per25 = round(stats.loc['25%'], 2)
    per50 = round(stats.loc['50%'], 2)
    per75 = round(stats.loc['75%'], 2)

    # Get position based on the column name
    pos = df.columns.to_list().index(col_name)
    
    for index, row in df.iterrows():
        pe = row[col_name]
        if pe == stats.loc['min']:
            tt_data[index][pos] = 'Lowest'
        elif pe == stats.loc['max']:
            tt_data[index][pos] = 'Hightest'
        elif pe <= per25:
            tt_data[index][pos] = '25% of companies under {}'.format(per25)
        elif pe <= per50:
            tt_data[index][pos] = '50% of companies under {}'.format(per50)
        elif pe <= per75:
            tt_data[index][pos] = '75% of companies under {}'.format(per75)
        else:
            tt_data[index][pos] = '25% of companies over {}'.format(per75)

# %%
# Initialize tool tip data - each column is set to '' for each row
tt_data = [['' for x in range(len(df.columns))] for y in range(len(df))]

# Gather tool tip data for indicators
populate_tt(df, tt_data, 'EPS (fwd)')
populate_tt(df, tt_data, 'P/E (fwd)')
populate_tt(df, tt_data, 'PEG')
populate_tt(df, tt_data, 'FCFY')
populate_tt(df, tt_data, 'PB')
populate_tt(df, tt_data, 'ROE')
populate_tt(df, tt_data, 'P/S (trail)')
populate_tt(df, tt_data, 'DPR')
populate_tt(df, tt_data, 'DY')
populate_tt(df, tt_data, 'CR')

# Create a tool tip DF
ttips = pd.DataFrame(data=tt_data, columns=df.columns, index=df.index)

# Add table caption and styles to DF
df.style.pipe(make_pretty).set_caption('Fundamental Indicators').set_table_styles(
    [{'selector': 'th.col_heading', 'props': 'text-align: center'},
     {'selector': 'caption', 'props': [('text-align', 'center'),
                                       ('font-size', '11pt'), ('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_f60a8 th.col_heading {
#   text-align: center;
# }
# #T_f60a8 caption {
#   text-align: center;
#   font-size: 11pt;
#   font-weight: bold;
# }
# #T_f60a8 .tt-add {
#   visibility: hidden;
#   position: absolute;
#   background-color: salmon;
#   color: black;
#   z-index: 1;
#   padding: 3px 3px;
#   margin: 2px;
# }
# #T_f60a8 #T_f60a8_row0_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col3 .tt-add::after {
#   content: "75% of companies under 16.36";
# }
# #T_f60a8 #T_f60a8_row0_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col4 .tt-add::after {
#   content: "75% of companies under 28.91";
# }
# #T_f60a8 #T_f60a8_row0_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col5 .tt-add::after {
#   content: "75% of companies under 3.18";
# }
# #T_f60a8 #T_f60a8_row0_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col6 .tt-add::after {
#   content: "25% of companies under 2.15";
# }
# #T_f60a8 #T_f60a8_row0_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col7 .tt-add::after {
#   content: "75% of companies under 20.69";
# }
# #T_f60a8 #T_f60a8_row0_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col8 .tt-add::after {
#   content: "75% of companies under 0.46";
# }
# #T_f60a8 #T_f60a8_row0_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col9 .tt-add::after {
#   content: "75% of companies under 13.12";
# }
# #T_f60a8 #T_f60a8_row0_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col10 .tt-add::after {
#   content: "50% of companies under 30.64";
# }
# #T_f60a8 #T_f60a8_row0_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col11 .tt-add::after {
#   content: "50% of companies under 0.01";
# }
# #T_f60a8 #T_f60a8_row0_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row0_col12 .tt-add::after {
#   content: "75% of companies under 1.68";
# }
# #T_f60a8 #T_f60a8_row1_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col3 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row1_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col4 .tt-add::after {
#   content: "25% of companies over 28.91";
# }
# #T_f60a8 #T_f60a8_row1_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col5 .tt-add::after {
#   content: "25% of companies under 0.69";
# }
# #T_f60a8 #T_f60a8_row1_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col6 .tt-add::after {
#   content: "50% of companies under 3.13";
# }
# #T_f60a8 #T_f60a8_row1_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col7 .tt-add::after {
#   content: "50% of companies under 11.13";
# }
# #T_f60a8 #T_f60a8_row1_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col8 .tt-add::after {
#   content: "25% of companies under 0.22";
# }
# #T_f60a8 #T_f60a8_row1_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col9 .tt-add::after {
#   content: "50% of companies under 5.19";
# }
# #T_f60a8 #T_f60a8_row1_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row1_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row1_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row1_col12 .tt-add::after {
#   content: "25% of companies under 1.07";
# }
# #T_f60a8 #T_f60a8_row2_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col3 .tt-add::after {
#   content: "25% of companies over 16.36";
# }
# #T_f60a8 #T_f60a8_row2_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col4 .tt-add::after {
#   content: "75% of companies under 28.91";
# }
# #T_f60a8 #T_f60a8_row2_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col5 .tt-add::after {
#   content: "25% of companies under 0.69";
# }
# #T_f60a8 #T_f60a8_row2_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col6 .tt-add::after {
#   content: "25% of companies under 2.15";
# }
# #T_f60a8 #T_f60a8_row2_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col7 .tt-add::after {
#   content: "25% of companies over 20.69";
# }
# #T_f60a8 #T_f60a8_row2_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col8 .tt-add::after {
#   content: "25% of companies over 0.46";
# }
# #T_f60a8 #T_f60a8_row2_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col9 .tt-add::after {
#   content: "Hightest";
# }
# #T_f60a8 #T_f60a8_row2_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col10 .tt-add::after {
#   content: "25% of companies under 10.64";
# }
# #T_f60a8 #T_f60a8_row2_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col11 .tt-add::after {
#   content: "50% of companies under 0.01";
# }
# #T_f60a8 #T_f60a8_row2_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row2_col12 .tt-add::after {
#   content: "Hightest";
# }
# #T_f60a8 #T_f60a8_row3_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col3 .tt-add::after {
#   content: "25% of companies under 8.84";
# }
# #T_f60a8 #T_f60a8_row3_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col4 .tt-add::after {
#   content: "50% of companies under 21.3";
# }
# #T_f60a8 #T_f60a8_row3_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col5 .tt-add::after {
#   content: "50% of companies under 1.69";
# }
# #T_f60a8 #T_f60a8_row3_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col6 .tt-add::after {
#   content: "75% of companies under 4.31";
# }
# #T_f60a8 #T_f60a8_row3_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col7 .tt-add::after {
#   content: "25% of companies under 6.28";
# }
# #T_f60a8 #T_f60a8_row3_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col8 .tt-add::after {
#   content: "50% of companies under 0.27";
# }
# #T_f60a8 #T_f60a8_row3_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col9 .tt-add::after {
#   content: "75% of companies under 13.12";
# }
# #T_f60a8 #T_f60a8_row3_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row3_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row3_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row3_col12 .tt-add::after {
#   content: "25% of companies over 1.68";
# }
# #T_f60a8 #T_f60a8_row4_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col3 .tt-add::after {
#   content: "25% of companies under 8.84";
# }
# #T_f60a8 #T_f60a8_row4_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col4 .tt-add::after {
#   content: "Hightest";
# }
# #T_f60a8 #T_f60a8_row4_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col5 .tt-add::after {
#   content: "Hightest";
# }
# #T_f60a8 #T_f60a8_row4_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col6 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row4_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col7 .tt-add::after {
#   content: "75% of companies under 20.69";
# }
# #T_f60a8 #T_f60a8_row4_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col8 .tt-add::after {
#   content: "50% of companies under 0.27";
# }
# #T_f60a8 #T_f60a8_row4_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col9 .tt-add::after {
#   content: "75% of companies under 13.12";
# }
# #T_f60a8 #T_f60a8_row4_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row4_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_f60a8 #T_f60a8_row4_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_f60a8 #T_f60a8_row4_col12 .tt-add::after {
#   content: "25% of companies over
